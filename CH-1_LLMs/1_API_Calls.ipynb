# %%
from dotenv import load_dotenv
load_dotenv()
import os

if os.environ.get("OPENAI_API_KEY"):
    print("OPENAI_API_KEY is Done !")
else:
    print("Need to set OPENAI_API_KEY in .env file")
# Out:
# OPENAI_API_KEY is Done !

# %% [markdown]
# ### OPENAI SDK

# %%
from openai import OpenAI

# Assumes OPENAI_API_KEY is set in your environment
client = OpenAI()

response = client.responses.create(
    model="gpt-5-mini",
    input = "Tell me a fun fact about Data Engineer"
    
)
print(response.output_text)
# Out:
# Fun fact: "Data engineer" is a relatively new job title — it only became common with the rise of big data (Hadoop/Spark era in the 2010s). Before that, the same work was split among DBAs, ETL developers and sysadmins, so data engineering is essentially a modern mash-up of those roles.
